# %%
def fib(n):
    sqroot = 5**0.5
    phi = (sqroot + 1) / 2
    return int(phi ** n / sqroot + 0.5)

print(fib(10))
# Out:
# 55

# %%
mile_distances = [1.0, 6.5, 17.4, 2.4, 9.2]

kilometer_distances= list(map(lambda x: x*1.6, mile_distances))

print(kilometer_distances)
# Out:
# [1.6, 10.4, 27.84, 3.84, 14.719999999999999]

# %%
'''

Напишите функцию, которая будет принимать на вход список email-адресов и выводить их распределение по доменным зонам.

Пример работы программы:
emails = [‘test@gmail.com’, ‘xyz@test.in’, ‘test@ya.ru’, ‘xyz@mail.ru’, ‘xyz@ya.ru’, ‘xyz@gmail.com’]

Результат:
gmail.com 2
test.in 1
ya.ru 2
mail.ru 1
'''

import re
 
emails = ['test@gmail.com', 'xyz@test.in', 'test@ya.ru', 'xyz@mail.ru', 'xyz@ya.ru', 'xyz@gmail.com']
 
def counting(emails: list) -> dict:
    dic = {}
    for email in emails:
        domain = email.split('@')[1]
        if domain in dic:
            dic[domain] += 1
        else:
            dic[domain] = 1
    return dic
 
for k, v in counting(emails).items():
    print(k, v)
# Out:
# gmail.com 2
# test.in 1
# ya.ru 2
# mail.ru 1

# %%
class AnyName:
    def method_1(self):
        self.currency = 'USD'
        
    def method_2(self):
        return self.currency

# %%
a = AnyName()
a.method_1()
print(a.method_2())
# Out:
# USD

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        
        def up(self):
            self.salary += 100
            
        def print_salary(self):
            print(f'Сотрудник {self.name}, зарплата {self.salary} рублей')
